# %%
# Telecharger la Dataset
# !gdown --id 16CG_f6pwnMpI2pX8EuLA8yrNu_Jv2vkL
# !unzip "/content/train.zip" -d "/content/"

# %%
import numpy as np
import os
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt
import cv2 as cv

# %%
from tensorflow.keras.models import Sequential
#from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import BatchNormalization
from sklearn.model_selection import train_test_split

imgs=[]

for i in range(1000):
   img = cv.imread("/content/train/cat."+str(i)+".jpg",0)
   resized_img=cv.resize(img,(128,128))
   #print(resized_img.shape)
   imgs.append(resized_img)

for i in range(1000):
   img = cv.imread("/content/train/dog."+str(i)+".jpg",0)
   resized_img=cv.resize(img,(128,128))
   #print(resized_img.shape)
   imgs.append(resized_img)

X = np.asarray(imgs)
X=X/255.0


print(X.shape)


Lcats=np.zeros((1000,1))
LDogs=np.ones((1000,1))

y=np.vstack((Lcats,LDogs))

#print(y)
plt.imshow(X[503])
# Out:
# (2000, 128, 128)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)

model = Sequential()
model.add(Conv2D(32,3,activation='relu',input_shape=(128,128,1)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64,3,activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128,3,activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu', kernel_initializer='he_normal', input_shape=(100,)))
model.add(Dense(1, activation='sigmoid'))



model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])

#model.fit(X_train, y_train, epochs=100, verbose=1)

# %%
model.evaluate(X_train,y_train)
# Out:
# 50/50 [==============================] - 1s 8ms/step - loss: 0.6929 - accuracy: 0.5119
# [0.6928557753562927, 0.5118749737739563]

# %%
history = model.fit(
  X_train,
  y_train,
  validation_data=(X_test,y_test),
  epochs=15
)

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(15)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# Epoch 1/15
# 50/50 [==============================] - 2s 24ms/step - loss: 0.7011 - accuracy: 0.4825 - val_loss: 0.6906 - val_accuracy: 0.6275
# Epoch 2/15
# 50/50 [==============================] - 1s 20ms/step - loss: 0.6808 - accuracy: 0.5775 - val_loss: 0.6908 - val_accuracy: 0.5675
# Epoch 3/15
# 50/50 [==============================] - 1s 20ms/step - loss: 0.6344 - accuracy: 0.6488 - val_loss: 0.6723 - val_accuracy: 0.6275
# Epoch 4/15
# 50/50 [==============================] - 1s 20ms/step - loss: 0.5890 - accuracy: 0.7138 - val_loss: 0.6404 - val_accuracy: 0.6450
# Epoch 5/15
# 50/50 [==============================] - 1s 20ms/step - loss: 0.5437 - accuracy: 0.7344 - val_loss: 0.6384 - val_accuracy: 0.6275
# Epoch 6/15
# 50/50 [==============================] - 1s 20ms/step - loss: 0.4699 - accuracy: 0.7688 - val_loss: 0.6574 - val_accuracy: 0.6500
# Epoch 7/15
# ...

# %% [markdown]
# # EXERCICE 2

# %%
#Telechargement de la dataset
# !gdown --id 1w_6x56IUsxvJKKt3Lj6LuxcehLt6EV7Y
# !unzip "/content/training.zip" -d "/content/"
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#  extracting: /content/training/9/1820.png
#  extracting: /content/training/9/18211.png
#   inflating: /content/training/9/18228.png
#  extracting: /content/training/9/18241.png
#  extracting: /content/training/9/18251.png
#  extracting: /content/training/9/1826.png
#  extracting: /content/training/9/18277.png
#  extracting: /content/training/9/18296.png
#   inflating: /content/training/9/183.png
#  extracting: /content/training/9/18350.png
#  extracting: /content/training/9/18355.png
#  extracting: /content/training/9/18374.png
#  extracting: /content/training/9/18377.png
#   inflating: /content/training/9/18382.png
#  extracting: /content/training/9/18387.png
#  extracting: /content/training/9/18401.png
#  extracting: /content/training/9/18405.png
#  extracting: /content/training/9/18415.png
#  extracting: /content/training/9/18437.png
#  extracting: /content/training/9/18441.png
# ...

# %%
import numpy as np
import os
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt
import cv2 as cv

# %%
from tensorflow.keras.models import Sequential
#from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Rescaling
from sklearn.model_selection import train_test_split

from skimage.feature import local_binary_pattern

imgs=[]
BATCH_SIZE = 32
IMG_SIZE = (32, 32)

data_dir='/content/training/'
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  shuffle=True,
  seed=123,
  image_size=(IMG_SIZE[0],IMG_SIZE[1]),
  batch_size=BATCH_SIZE)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  shuffle=True,
  subset="validation",
  seed=123,
  image_size=(IMG_SIZE[0],IMG_SIZE[1]),
  batch_size=BATCH_SIZE)

image_batch, label_batch = next(iter(train_ds))
print(image_batch.shape)
# Out:
# Found 60000 files belonging to 10 classes.
# Using 48000 files for training.
# Found 60000 files belonging to 10 classes.
# Using 12000 files for validation.
# (32, 32, 32, 3)

# %%
model = Sequential()
model.add(Rescaling(1./255, input_shape=(32,32,3)),)
model.add(Conv2D(16,3,activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(64, activation='relu', kernel_initializer='he_normal', input_shape=(100,)))
model.add(Dense(10, activation='softmax'))

# %%
initial_epochs = 5
base_learning_rate = 0.01
model.compile(
    optimizer=keras.optimizers.Adam(base_learning_rate),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
#loss0, accuracy0 = model.evaluate(val_ds)

history = model.fit(train_ds,
                    epochs=initial_epochs,
                    validation_data=val_ds)
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 28s 11ms/step - loss: 0.1702 - accuracy: 0.9483 - val_loss: 0.1029 - val_accuracy: 0.9718
# Epoch 2/5
# 1500/1500 [==============================] - 17s 11ms/step - loss: 0.0913 - accuracy: 0.9731 - val_loss: 0.1107 - val_accuracy: 0.9737
# Epoch 3/5
# 1500/1500 [==============================] - 16s 11ms/step - loss: 0.0783 - accuracy: 0.9767 - val_loss: 0.1380 - val_accuracy: 0.9697
# Epoch 4/5
# 1500/1500 [==============================] - 18s 12ms/step - loss: 0.0679 - accuracy: 0.9807 - val_loss: 0.1396 - val_accuracy: 0.9690
# Epoch 5/5
# 1500/1500 [==============================] - 17s 11ms/step - loss: 0.0616 - accuracy: 0.9840 - val_loss: 0.1703 - val_accuracy: 0.9689

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(5)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input

from keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.preprocessing import image


conv_b = VGG16(weights='imagenet',include_top=False,input_shape=(32, 32,3))
conv_b.summary()
# Out:
# ...
# 58900480/58889256 [==============================] - 0s 0us/step
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 32, 32, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 32, 32, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 16, 16, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 16, 16, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 16, 16, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 8, 8, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 8, 8, 256)         295168
#
#  block3_conv2 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_conv3 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 4, 4, 512)         1180160
#
# ...

# %%
conv_b.trainable=False
conv_b.output
# Out:
# <KerasTensor: shape=(None, 1, 1, 512) dtype=float32 (created by layer 'block5_pool')>

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras import models


modelVGG16 = models.Sequential()
modelVGG16.add(conv_b)
modelVGG16.add(Flatten())
modelVGG16.add(Dense(64, activation='relu', kernel_initializer='he_normal', input_shape=(100,)))
modelVGG16.add(Dense(10, activation='softmax'))

modelVGG16.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  vgg16 (Functional)          (None, 1, 1, 512)         14714688
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 64)                32832
#
#  dense_3 (Dense)             (None, 10)                650
#
# ...
# Total params: 14,748,170
# Trainable params: 33,482
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# # Model VGG16

# %%
initial_epochs = 5
base_learning_rate = 0.01
modelVGG16.compile(
    optimizer=keras.optimizers.Adam(base_learning_rate),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
#loss0, accuracy0 = model.evaluate(val_ds)

epochs=50
history_AVG  = modelVGG16.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/50
# 1500/1500 [==============================] - 549s 366ms/step - loss: 0.4921 - accuracy: 0.8648 - val_loss: 0.3745 - val_accuracy: 0.8977
# Epoch 2/50
# 1500/1500 [==============================] - 547s 365ms/step - loss: 0.3435 - accuracy: 0.8977 - val_loss: 0.3116 - val_accuracy: 0.9086
# Epoch 3/50
# 1500/1500 [==============================] - 535s 357ms/step - loss: 0.3329 - accuracy: 0.9037 - val_loss: 0.3347 - val_accuracy: 0.9128
# Epoch 4/50
# 1500/1500 [==============================] - 534s 356ms/step - loss: 0.3238 - accuracy: 0.9111 - val_loss: 0.3276 - val_accuracy: 0.9072
# Epoch 5/50
# 1500/1500 [==============================] - 521s 347ms/step - loss: 0.3219 - accuracy: 0.9125 - val_loss: 0.4004 - val_accuracy: 0.8967
# Epoch 6/50
# 1500/1500 [==============================] - 527s 351ms/step - loss: 0.3120 - accuracy: 0.9161 - val_loss: 0.3330 - val_accuracy: 0.9198
# Epoch 7/50
# ...

# %%
acc = history_AVG.history['accuracy']
val_acc = history_AVG.history['val_accuracy']

loss = history_AVG.history['loss']
val_loss = history_AVG.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Model VGG16 Fine tuning

# %%
conv_b.trainable = True
print("Number of layers in the base model: ", len(conv_b.layers))
fine_tune_at = 100
for layer in conv_b.layers[:fine_tune_at]:
  layer.trainable = False

model.compile(loss=keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer = keras.optimizers.RMSprop(learning_rate=0.0001),
              metrics=['accuracy'])

model.summary()
# Out:
# Number of layers in the base model:  19
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  rescaling (Rescaling)       (None, 32, 32, 3)         0
#
#  conv2d (Conv2D)             (None, 30, 30, 16)        448
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 16)       0
#  )
#
#  flatten (Flatten)           (None, 3600)              0
#
#  dense (Dense)               (None, 64)                230464
#
#  dense_1 (Dense)             (None, 10)                650
#
# ...
# Total params: 231,562
# Trainable params: 231,562
# Non-trainable params: 0
# _________________________________________________________________

# %%
initial_epochs = 5
base_learning_rate = 0.01
modelVGG16.compile(
    optimizer=keras.optimizers.Adam(base_learning_rate),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
#loss0, accuracy0 = model.evaluate(val_ds)

epochs=50
history_fine  = modelVGG16.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/50
# 1500/1500 [==============================] - 21s 13ms/step - loss: 0.3002 - accuracy: 0.9262 - val_loss: 0.6622 - val_accuracy: 0.9002
# Epoch 2/50
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.2951 - accuracy: 0.9240 - val_loss: 0.5117 - val_accuracy: 0.9124
# Epoch 3/50
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.2881 - accuracy: 0.9289 - val_loss: 0.5245 - val_accuracy: 0.9137
# Epoch 4/50
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.3158 - accuracy: 0.9186 - val_loss: 0.5100 - val_accuracy: 0.9132
# Epoch 5/50
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.2892 - accuracy: 0.9273 - val_loss: 0.5746 - val_accuracy: 0.9103
# Epoch 6/50
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.3122 - accuracy: 0.9216 - val_loss: 0.5171 - val_accuracy: 0.9196
# Epoch 7/50
# ...

# %%
acc = history_fine.history['accuracy']
val_acc = history_fine.history['val_accuracy']

loss = history_fine.history['loss']
val_loss = history_fine.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Model resnet50

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing.image import load_img, img_to_array



conv_r = ResNet50(weights='imagenet',include_top=False,input_shape=(32, 32,3))
conv_r.summary()
# Out:
# ...
# 94781440/94765736 [==============================] - 0s 0us/step
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv1_pad (ZeroPadding2D)      (None, 38, 38, 3)    0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 16, 16, 64)   9472        ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalization)  (None, 16, 16, 64)   256         ['conv1_conv[0][0]']
#
#  conv1_relu (Activation)        (None, 16, 16, 64)   0           ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 18, 18, 64)   0           ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 8, 8, 64)     0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 8, 8, 64)     4160        ['pool1_pool[0][0]']
#
# ...

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras import models


modelResNet = models.Sequential()
modelResNet.add(conv_r)
modelResNet.add(Flatten())
modelResNet.add(Dense(64, activation='relu', kernel_initializer='he_normal', input_shape=(100,)))
modelResNet.add(Dense(10, activation='softmax'))

modelResNet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  resnet50 (Functional)       (None, 1, 1, 2048)        23587712
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 64)                131136
#
#  dense_1 (Dense)             (None, 10)                650
#
# ...
# Total params: 23,719,498
# Trainable params: 23,666,378
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
initial_epochs = 5
base_learning_rate = 0.01
modelResNet.compile(
    optimizer=keras.optimizers.Adam(base_learning_rate),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
#loss0, accuracy0 = model.evaluate(val_ds)

epochs=50
history_ResNet  = modelResNet.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/50
# 1500/1500 [==============================] - 91s 49ms/step - loss: 1.0733 - accuracy: 0.6577 - val_loss: 0.4765 - val_accuracy: 0.8812
# Epoch 2/50
# 1500/1500 [==============================] - 73s 49ms/step - loss: 0.3061 - accuracy: 0.9173 - val_loss: 1.8248 - val_accuracy: 0.5272
# Epoch 3/50
# 1500/1500 [==============================] - 73s 49ms/step - loss: 0.3661 - accuracy: 0.8918 - val_loss: 0.3311 - val_accuracy: 0.9078
# Epoch 4/50
# 1500/1500 [==============================] - 73s 49ms/step - loss: 0.4219 - accuracy: 0.8754 - val_loss: 0.4035 - val_accuracy: 0.8511
# Epoch 5/50
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.3088 - accuracy: 0.9102 - val_loss: 0.2819 - val_accuracy: 0.9291
# Epoch 6/50
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.1966 - accuracy: 0.9464 - val_loss: 0.1186 - val_accuracy: 0.9653
# Epoch 7/50
# ...

# %%
modelResNet.evaluate(val_ds)
# Out:
# 375/375 [==============================] - 7s 18ms/step - loss: 0.0811 - accuracy: 0.9794
# [0.0811309814453125, 0.9794166684150696]

# %%
acc = history_ResNet.history['accuracy']
val_acc = history_ResNet.history['val_accuracy']

loss = history_ResNet.history['loss']
val_loss = history_ResNet.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Model resnet50 Fine tuning

# %%
conv_r.trainable = True
print("Number of layers in the base model: ", len(conv_r.layers))
fine_tune_at1 = 100
for layer in conv_r.layers[:fine_tune_at1]:
  layer.trainable = False

modelResNet.compile(loss=keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer = keras.optimizers.RMSprop(learning_rate=0.0001),
              metrics=['accuracy'])

modelResNet.summary()
# Out:
# Number of layers in the base model:  175
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  resnet50 (Functional)       (None, 1, 1, 2048)        23587712
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 64)                131136
#
#  dense_1 (Dense)             (None, 10)                650
#
# ...
# Total params: 23,719,498
# Trainable params: 19,584,714
# Non-trainable params: 4,134,784
# _________________________________________________________________

# %%
initial_epochs = 5
base_learning_rate = 0.01
modelResNet.compile(
    optimizer=keras.optimizers.Adam(base_learning_rate),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
#loss0, accuracy0 = model.evaluate(val_ds)

epochs=50
history_fine1  = modelResNet.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/50
# 1500/1500 [==============================] - 63s 39ms/step - loss: 0.1118 - accuracy: 0.9707 - val_loss: 0.0759 - val_accuracy: 0.9800
# Epoch 2/50
# 1500/1500 [==============================] - 57s 38ms/step - loss: 0.1038 - accuracy: 0.9744 - val_loss: 0.0761 - val_accuracy: 0.9795
# Epoch 3/50
# 1500/1500 [==============================] - 57s 38ms/step - loss: 0.1461 - accuracy: 0.9669 - val_loss: 0.0788 - val_accuracy: 0.9797
# Epoch 4/50
# 1500/1500 [==============================] - 58s 38ms/step - loss: 0.0968 - accuracy: 0.9740 - val_loss: 0.0742 - val_accuracy: 0.9810
# Epoch 5/50
# 1500/1500 [==============================] - 57s 38ms/step - loss: 0.0993 - accuracy: 0.9745 - val_loss: 0.0848 - val_accuracy: 0.9795
# Epoch 6/50
# 1500/1500 [==============================] - 58s 38ms/step - loss: 0.0940 - accuracy: 0.9752 - val_loss: 0.0834 - val_accuracy: 0.9785
# Epoch 7/50
# ...

# %%
acc = history_fine1.history['accuracy']
val_acc = history_fine1.history['val_accuracy']

loss = history_fine1.history['loss']
val_loss = history_fine1.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
